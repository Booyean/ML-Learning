# %%
# %matplotlib inline 
#这是魔法命令，设置绘图模式为"inline"模式。即所有绘图都会嵌入到notebook中，与代码在同一页面上显示，方便查看和阅读(注意这一行的代码需要单独提行写)
import random #导入random模块，提供生成随机数的函数
import torch #导入pytorch的库。为代码实现提供框架
from d2l import torch as d2l #从d2l库中导入pytorch的相关模块，并命名为d2l

# %% [markdown]
# 使用参数$w=[2,-3.4]^{T}$、$b=4.2$、和项e生成数据集和标签

# %%
def synthetic_data(w,b,num_examples):
    """生成线性函数""" #末项是标准差为0.01的高斯噪声
    X = torch.normal(0, 1, (num_examples, len(w)))
    # 生成矩阵X
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1,1))
    
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print('features:', features[0], '\nlabel:', labels[0])
# Out:
# features: tensor([-0.1906,  0.2660])
# label: tensor([2.9134])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);
